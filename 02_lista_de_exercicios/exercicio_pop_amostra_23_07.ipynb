# %% [markdown]
# ## Lista de exercícios da aula de População e Amostragem
#
# Exercícios referentes à aula vista no dia 23/07, com base no vídeo [APRENDA ESTATÍSTICA 01: População e Amostra](https://www.youtube.com/watch?v=4CcgZXXIl7o), do canal TeoMeWhy

# %% [markdown]
# O que é estatística?

# %%
# Sua resposta aqui

# %% [markdown]
# Qual a diferença entre população e amostra?

# %%
# Sua resposta aqui

# %% [markdown]
# Por que optamos por utilizar uma amostra em vez da população?

# %%
# Sua resposta aqui

# %% [markdown]
# Qual o objetivo principal de realizar uma amostragem aleatória?

# %%
# Sua resposta aqui

# %% [markdown]
# O que significa dizer que uma amostra deve ser representativa da população?

# %%
# Sua resposta aqui

# %% [markdown]
# Qual a diferença entre um parâmetro e um estimador?

# %%
# Sua resposta aqui

# %% [markdown]
# Como podemos definir a unidade amostral?

# %%
# Sua resposta aqui

# %% [markdown]
# Qual a diferença entre uma variável e uma observação em um dataset?

# %%
# Sua resposta aqui
